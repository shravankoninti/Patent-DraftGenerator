# %%
## Kaggle Dataset is downloaded from here : 
# https://www.kaggle.com/c/uspto-explainable-ai/data
# USPTO - Explainable AI for Patent Professionals
# Help patent professionals understand AI results through a familiar query language
# patent_data has all .parquet files downloaded

# %% [markdown]
# ## Check sample file

# %%
import pandas as pd

# Path to your .parquet file
parquet_file_path = "D:\\Topcoder\\patent_documentation\\patent_data\\1837_12.parquet"

# Read the .parquet file
df = pd.read_parquet(parquet_file_path)

# Display the contents of the .parquet file
print(df)

# If you want to display the first few rows
print(df.head())
# Out:
#    publication_number                                              title  \
# 0            US-492-A                                        Machine foe
# 1            US-493-A                                      Cooking-stove
# 2            US-494-A                           Steering wheel for ships
# 3            US-495-A                           Machine for sizing paper
# 4            US-496-A  Mode of com-stbuctiire sawmills fob sawing timber
# 5            US-497-A  Improvement in the machine for preparing ice f...
# 6            US-498-A  Improvement in mode of constructing saw-cylind...
# 7            US-499-A                   Machine fob steaming and mashing
# 8            US-500-A                        Improved excavating-machine
# 9            US-501-A                               Improvement in plows
# 10           US-502-A                                      Through trees
# 11           US-503-A  Improvement in the manufacture of india-rubber...
# 12           US-504-A  Action of pianofortes and mode of giving stabi...
# 13           US-505-A                                            Mode of
# 14           US-506-A                                           Doou-sps
# 15           US-507-A                                      John crabtree
# 16           US-508-A                                           Jordan l
# 17           US-509-A                           Waterproof mail-carriage
# 18           US-510-A                                              soeel
# 19           US-511-A    Improved mode of coloring and finishing leather
# 20           US-512-A                                        Water-wheel
# 21           US-513-A                                            gleason
# 22           US-514-A                    Cccktstrtrctxchsr of boot-trees
# 23           US-515-A                  Machine for threshing clover-seed
# 24           US-516-A     Improved machine for manufacturing wood-screws
# 25           US-518-A             Improvement in horizontal water-wheels
# 26           US-519-A                                    Crrcumfekjsnter
# 27           US-520-A  Improvement in the construction of trunks and ...
# 28           US-521-A  Spark-catcher eor arresting awd extinguishing ...
# 29           US-522-A                                        John thomas
# 30           US-523-A    Mode of construction of suction and force pumps
# 31           US-524-A      Improvement en machinery for spinning tobacco
# 32           US-525-A                         Machine for hulling clovee
# 33           US-526-A                                        Machine foe
# 34           US-527-A                                        Machine for
# 35           US-528-A                      Improvement in cooking-stoves
# 36           US-529-A                                 Secret safety-lock
# 37           US-530-A                                  Threshing-machine
# 38           US-531-A                                        Machine fob
# 39           US-532-A  Machine for reducing and cutting dye woods and...
# 40           US-533-A                                   Truss for hermta
# 41           US-534-A                           Improved steam-generator
# 42           US-535-A                                Safety railroad-gar
# 43           US-536-A                Beady binder for binding newspapers
# 44           US-537-A          Fastening- for window blinds and shutters
# 45           US-538-A  Self-separating link for connecting railroad-c...
# 46           US-539-A     Standard measurer for taking measure for coats
# 47           US-540-A                 Construction of locomotive-engines
# 48           US-541-A                                     Daniel desmond
# 49           US-542-A        Machine for ti-ibeshing and cleaning g-rain
# 50           US-543-A                                   Carington wilson
# 51           US-544-A    Construction of heddles and harness eor weavers
# 52           US-545-A        Method of making fastenings for saddle-bags
#
#    abstract claims                                        description
# 0                   Umrnn srafrns&#34; ZEBULON SARGENT, or coNTooo...
# 1                   N. WALKER.  \n Cooking Stove.  \n Patented Deo...
# 2                   4 UNXTED srnrns PATENT OBFKCE.  \n ANDREW MORS...
# 3                   UNITED STATES PATENT OFFICE. Y  \n JOI-IN AMES...
# 4                   UNTTan sTaTns PATE T OFFICE.  \n JOHN AMBLER, ...
# 5                   NATHANIEL J. VVYETH, OF CAMBRIDGE, MASSACHUSET...
# 6                   J. IDLER. Sa w Qylinder for Cotton Gins.  \n P...
# 7                   UNITED sri-iras PATENTori-non.Y  \n JOHN DIMM,...
# 8                   &#39; T. GLATON.  \n Ditching Plow.  \n Patent...
# 9                   UNITED STATES ,PATENT OFFICE.  \n STEPHEN Meco...
# 10                  AM PHOTO-LITHO. C0. NYY EEEEEEEEEEEEEEE S) ITE...
# 11                  UNITED STATES PATENT OFFICE.  \n STEPHEN 0. SM...
# 12                  T. LOUD.  \n . Piano Forte. v NO. 504. Ptented...
# 13                  2 Sheets-Sheet 1. J. G. H&#39;ATHAWAY. i  \n C...
# 14                  UNrrED STATES rATENT oFFioE.  \n THOMAS THORPE...
# 15                  UETTED sTATEs PATENT oEErcE.  \n JOHN CRABTREE...
# 16                  J.- L. 1M0TT.  \n Stove.  \n No. 508. Patented...
# 17                  B. B. PLEASANTS.  \n Carriage.  \n Patented De...
# 18                  M; sonnn, or PARIS, RANCE.  \n &#39; METHOD OF...
# 19                  of the top cylinder.  \n we STATES PATENT OFFI...
# 20                  UNITED STATES PATENT OFFICE.  \n CHARLES GOULD...
# 21                  H. GLEASON. Cooking Stov.  \n N0. 513. Patente...
# 22                  UNITED STATES PATENT,  \n DAVID HASTINGS, OF D...
# 23                  J.- BRO0KS.  \n y Clover Huller.  \n Patented ...
# 24                  3 Sheets-Sh.eef 1&#39;.  \n  C. 0. READ. v Mac...
# 25                  UNITED STATES PATENT OFFICE.  \n SAMUEL CURTIS...
# 26                  J. MCCANN.  \n &#39; Surveying Instrument.  \n...
# 27                  UNITED STATESl PATENT Ormes.  \n - Mn&#39;rHIA...
# 28                  UNITED STATES PATENT OFFICE- WILLIAM DUFF, OF ...
# 29                  UNITED STATES PATENT OFFICE.  \n  IV- JOHN THO...
# 30                  UNTTED sTATEs PATENT OFFICE.  \n JONATHAN STEV...
# 31                  &#39;H. M. SMITH.  \n Preparing Tohacco.  \n P...
# 32                  w. BARTON.  \n Clover Hulleii- --Patented Dec....
# 33                  rrnn Marwan@ oFFicE.  \n ERASTUS TRACY, OF POU...
# 34                  UNITED STATES PATENT OFFICE. 1  \n HARVEY HOLM...
# 35                  v J. HUTCHINSON.  \n  Cobking Stove;  \n No. 5...
# 36                  TD STATES PATENT OFFICE WILLIAM HOBBS, OF CABO...
# 37                  ( LIL/L: /M4 J ,7 c .gwt yiw A. W. BOWLING.  \...
# 38                  UNITED STATES PATENT OFFICE.  \n CLIVER WYMAN,...
# 39                  A. McMILLEN.  \n Bark Mill.  \n Patented Dec. ...
# 40                  UNITED sTATEs PATENT oEEioE.  \n JOSIAH HUNGER...
# 41                  NITED &#39;STATES PATENT Critica,  \n WILLAM C...
# 42                  ; UNITE STATES PATENT OFFICE.  \n WILLIAM KINK...
# 43                  UNITED STATES PATENT OFFICE.  \n EZRA RIPLEY, ...
# 44                  June 1, 1915.  \n DRAWING A careful search has...
# 45                  HUNT &amp; BROWN.  \n  CarCoupling.  \n Patent...
# 46                  E. BARBER.  \n Taiiors Measure.  \n N0. 539. v...
# 47                  UNITED sTaTns PATENT onirica.  \n SAMUEL \VRIG...
# 48                  D. DESMOND.  \n I Fire Place. N0. 541  \n Pate...
# 49                  . I 2 SheetsSheet&#39; 2 J. Ai &amp; H. A. PIT...
# 50                  c WILSON. J r.  \n  Cooking Stove. v No. 543. ...
# 51                  STATES FATENT OFFCE.  \n BENJN. HARTFORD AND W...
# 52                  i UNITED STATES PATENT OFFICE.`  \n ALVIN NORT...
#   publication_number                                              title  \
# 0           US-492-A                                        Machine foe
# 1           US-493-A                                      Cooking-stove
# 2           US-494-A                           Steering wheel for ships
# 3           US-495-A                           Machine for sizing paper
# 4           US-496-A  Mode of com-stbuctiire sawmills fob sawing timber
#
#   abstract claims                                        description
# 0                  Umrnn srafrns&#34; ZEBULON SARGENT, or coNTooo...
# 1                  N. WALKER.  \n Cooking Stove.  \n Patented Deo...
# 2                  4 UNXTED srnrns PATENT OBFKCE.  \n ANDREW MORS...
# 3                  UNITED STATES PATENT OFFICE. Y  \n JOI-IN AMES...
# 4                  UNTTan sTaTns PATE T OFFICE.  \n JOHN AMBLER, ...

# %%
df.columns
# Out:
# Index(['publication_number', 'title', 'abstract', 'claims', 'description'], dtype='object')

# %%
df[df['publication_number'] == 'US-496-A']
# Out:
#   publication_number                                              title  \
# 4           US-496-A  Mode of com-stbuctiire sawmills fob sawing timber
#
#   abstract claims                                        description
# 4                  UNTTan sTaTns PATE T OFFICE.  \n JOHN AMBLER, ...

# %% [markdown]
# ## Check sample file - for non-abstract columns files

# %%
import os
import random
import pandas as pd
import pyarrow.parquet as pq

def load_random_parquet_files(folder_path, num_files=3):
    try:
        print(f"Searching for parquet files in: {folder_path}")
        
        # Ensure the folder path exists
        if not os.path.exists(folder_path):
            raise FileNotFoundError(f"The folder path does not exist: {folder_path}")
        
        # List all .parquet files in the directory
        parquet_files = [file for file in os.listdir(folder_path) if file.endswith('.parquet')]
        
        if not parquet_files:
            print(f"No parquet files found in {folder_path}")
            return None
        
        print(f"Found {len(parquet_files)} parquet files")
        
        # Select random files
        random_files = random.sample(parquet_files, min(num_files, len(parquet_files)))
        print(f"Randomly selected {len(random_files)} files: {random_files}")

        dfs = []
        for file_name in random_files:
            file_path = os.path.join(folder_path, file_name)
            print(f"Loading file: {file_path}")
            parquet_file = pq.ParquetFile(file_path)
            table = parquet_file.read()
            df = table.to_pandas()
            dfs.append(df)
        
        if len(dfs) > 1:
            result_df = pd.concat(dfs, ignore_index=True)
        elif len(dfs) == 1:
            result_df = dfs[0]
        else:
            result_df = None
        
        print(f"Total rows in combined DataFrame: {len(result_df) if result_df is not None else 0}")
        return result_df
    
    except Exception as e:
        print(f"An error occurred: {str(e)}")
        return None

# Usage
folder_path = r"D:\Topcoder\patent_documentation\patent_data"  # Note the 'r' prefix for raw string
random_df = load_random_parquet_files(folder_path)

if random_df is not None:
    print(random_df.describe())
else:
    print("Failed to load parquet files.")
# Out:
# Searching for parquet files in: D:\Topcoder\patent_documentation\patent_data
# Found 2251 parquet files
# Randomly selected 3 files: ['1975_3.parquet', '1889_5.parquet', '1891_9.parquet']
# Loading file: D:\Topcoder\patent_documentation\patent_data\1975_3.parquet
# Loading file: D:\Topcoder\patent_documentation\patent_data\1889_5.parquet
# Loading file: D:\Topcoder\patent_documentation\patent_data\1891_9.parquet
# Total rows in combined DataFrame: 9063
#        publication_number   title abstract claims description
# count                9063    9063     9063   9063        9063
# unique               9063    8274     5245   5228        9059
# top          US-3868726-A  Island
# freq                    1      49     3807   3836           5

# %%
import pandas as pd

# Assuming you've already created the DataFrame named unique_patents_df

# View the first 5 rows (default for head())
print(unique_patents_df.head())

# If you want to see more or fewer rows, you can specify a number:
# For example, to see the first 3 rows:
print(unique_patents_df.head(3))

# To see all columns clearly, you might want to display them vertically:
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', None)  # Use full width of the notebook/console
pd.set_option('display.max_colwidth', None)  # Show full content of each column

# Now display the first row vertically
print(unique_patents_df.iloc[0].to_string())

# If you want to see specific columns, you can do:
columns_to_show = ['publication_number', 'title', 'abstract']
print(unique_patents_df[columns_to_show].head())
# Out:
#   publication_number                                    title abstract claims  \
# 0        US-618818-A                                William t
# 1        US-618819-A                   Portable fence-machine
# 2        US-618820-A                                   Qtjier
# 3        US-618821-A                            Document-file
# 4        US-618822-A  Window-screen and controlling apparatus
#
#                                          description
# 0  N0. 618,818. Patentedfeb. 7, |899.  \n W. T. A...
# 1  Patented Feb. 7, I899.  \n  T. J. ARMSTRONG. P...
# 2  No. 6|8,820. Patented Feb. 7, 1899.  \n  F. E....
# 3  No. s|8,s2|. Patented Feb. 7, I899. A. c. BARL...
# 4  No. 6I8,822. Patented Feb. 7, I899.  \n  T. E....
#   publication_number                   title abstract claims  \
# 0        US-618818-A               William t
# 1        US-618819-A  Portable fence-machine
# 2        US-618820-A                  Qtjier
#
#                                          description
# 0  N0. 618,818. Patentedfeb. 7, |899.  \n W. T. A...
# 1  Patented Feb. 7, I899.  \n  T. J. ARMSTRONG. P...
# 2  No. 6|8,820. Patented Feb. 7, 1899.  \n  F. E....
# publication_number                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# abstract                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# claims                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# description           N0. 618,818. Patentedfeb. 7, |899.  \n W. T. ADAMS Doon HoLDE.  \n (Application led May 31, 1898.)  \n (No Model.)  \n &#39;VVitneSsel` Inventor @@LJDM A-tto r&#39;n ey 45 casing.  \n &#39; iran STATES BEIGE,  \n dArtnr XVILLIAM T. ADAMS, OF READING, PENNSYLVANIA, ASSIGNOR TO THE READING HARDWARE COMPANY, OF SAME PLACE.  \n ADOOR-HOLDER.  \n SPECIFICATION forming part of Letters Patent No. 618,818, dated February 7, 1899.  \n Application filed May 31, 1898. Serial No. 682,179 (No model.)  \n T @ZZ whom t may concern.-  \n  Be it known that I, WILLIAM T. ADAMS, a citizen of the United States of America, and a resident of Reading, county of Berks, State of Pennsylvania, have invented certain new and useful Improvements in Door-Holders, of which the following is a specification.  \n  My invention relates to devices for holding doors open in any desired position; and it xo consists in certain novel features which are fully described in connection with the accompanying drawings and are particularly set out in the claims.  \n Figure l is a sectional elevation of the de- &#39;r 5 vice as applied to a door, the bolt being shown in its normal raised position. Fig. 2 is a side elevation showing the bolt lowered to engage the floor, and thereby hold the door. Fig. 3 is a rear elevation of the same, and Fig. 4 is zo a cross-section on the line oo of Fig. l.  \n  O represents the casing, in which the pushbolt D E is mounted. It is intended to be fastened to the face A of a door in such a manner as to bring the bottom of the bolt,  \n  when the latter is in its normal raised position, about level with the bottom edge d of the door, so as to ordinarily safely clear the iioor B.  \n The bolt, as shown, is composed of an up- 3&#39;0 per part D and a lower part E, the latter being preferably of tubular form, having at the lower end a cushion-tip e and mounted upon a stem d2 of the upper part D, to `which it is attached by means of a pin e and upon which. 3 5 it is capable of a limited movement against a spring G, the tension of which normally maintains it in extended or projected position upon the stem e. The main part D of the bolt is suitably guided in the casing, and in 4o connection with the relatively-movable lower part E is normally raised to the position indicated in Fig. l by means of a spring F, a shoulder d of the bolt being in this position in contact with a stop c2 on the interior of the The top d4 of the bolt is suitably shaped to receive pressure from the foot of the operator.  \n In order to hold the bolt in the lowered position, to which it is necessary to move it in 5o order to press the tip e against the floor and thereby hold the door, I provide a locking mechanism, which consists, as shown, of a trigger I-I, having detents h, which are normally pressed into engagement with toothed edges CZ on the body portion D of the bolt. As shown, these parallel toothed edges d d are separated, so as to allow the trigger to be located between them, the detents h being extended laterally to engage them. This trigger is pivotally mounted on a lug c, provided on the interior of the casing, and it is merely concaved to form a bearing on the lug instead of being pinned thereto, thereby avoiding any drilling or nishing whatever. To avoid its becoming disengaged from the lug e when the parts have been put together and to take the upward strain of the bolt, stop-lugs c are also provided in the casing at a sufficient distance from the lug c to just permit the trigger to swing freely upon the latter without allowing it longitudinal movement. A spring J normally presses it into engagement with the toothed edges d of the bolt, and it projects through the casing at c3 sufficiently to be readily operated by the foot for the pu-rpose of throwing -it out of engagement therewith to release the bolt.  \n The device having been properly fastened to the door, the latter may be firmly held .by contact with the floor, after which any furt ...
#   publication_number                                    title abstract
# 0        US-618818-A                                William t
# 1        US-618819-A                   Portable fence-machine
# 2        US-618820-A                                   Qtjier
# 3        US-618821-A                            Document-file
# 4        US-618822-A  Window-screen and controlling apparatus

# %% [markdown]
# # Main File generated Here for selecting Finetuned dataset

# %% [markdown]
# ### The idea is to select all the patents with abstract not null values . This will ensure I have all the columns information.
# ### Main idea is to have the important columns like title, abstract, claims, description from 50 files of .parquet files. Please remember that each .parquet file have many patent publications.

# %%
import pandas as pd
import pyarrow.parquet as pq
import os
import random
from tqdm import tqdm
import time

# Timer start
start_time = time.time()
def load_patents_with_abstracts_from_random_files(folder_path, num_files=50):
    # Get all parquet files in the directory
    all_parquet_files = [f for f in os.listdir(folder_path) if f.endswith('.parquet')]
    
    # Randomly select num_files
    selected_files = random.sample(all_parquet_files, min(num_files, len(all_parquet_files)))
    
    all_patents = []
    
    print(f"Processing {len(selected_files)} randomly selected files")
    
    # Use tqdm for the progress bar
    for file in tqdm(selected_files, desc="Processing files"):
        file_path = os.path.join(folder_path, file)
        
        try:
            # Read the parquet file
            df = pd.read_parquet(file_path)
            
            # Filter for non-null abstracts
            df_with_abstract = df[df['abstract'].notna()]
            
            all_patents.append(df_with_abstract)
        except Exception as e:
            print(f"Error processing file {file}: {str(e)}")
    
    # Combine all dataframes
    combined_df = pd.concat(all_patents, ignore_index=True)
    
    # Get unique patents based on abstract
    unique_patents = combined_df.drop_duplicates(subset='abstract')
    
    # Sample up to 1000 patents
    sample_1000 = unique_patents.sample(n=min(1000, len(unique_patents)))
    
    # Save the sample to CSV
    sample_1000.to_csv('random_1000_abstractnotnull_1.csv', index=False)
    # unique_patents.to_csv('unique_patents_abstractnotnull_200files.csv', index=False)
    
    # print(f"Sample of 5 patents saved to 'abstractnotnull.csv'")
    print(f"Total patents processed: {len(combined_df)}")
    print(f"Total unique patents with non-null abstracts: {len(unique_patents)}")
    
    return unique_patents

# Usage
folder_path = r"D:\Topcoder\patent_documentation\patent_data"
result = load_patents_with_abstracts_from_random_files(folder_path, num_files=50)

# Timer end
end_time = time.time()
execution_time = end_time - start_time

print(f"Execution time: {execution_time} seconds")
# Out:
# Processing 50 randomly selected files
# Processing files: 100%|████████████████████████████████████████████████████████████████| 50/50 [00:52<00:00,  1.06s/it]
# Total patents processed: 376878
# Total unique patents with non-null abstracts: 255805
# Execution time: 125.4606397151947 seconds

# %%
import pandas as pd
df = pd.read_csv("random_1000_abstractnotnull_1.csv")
df.head()
# Out:
#   publication_number                                              title  \
# 0     US-11114351-B2  Dummy element and method of examining defect o...
# 1     US-10946109-B2            Polymer-type fluorescent molecule probe
# 2     US-11112260-B2  Geospatial navigation methods and systems for ...
# 3     US-10940384-B2  Inciting user action for motion sensor calibra...
# 4   US-2021298305-A1  Use of a difluoro-(2-hydroxypropyl)pyridine co...
#
#                                             abstract  \
# 0  A dummy element includes: a semiconductor subs...
# 1  The present invention provides a fluorescent m...
# 2  An exemplary geospatial navigation system defi...
# 3  In a method of motion sensor calibration, a mo...
# 4  The present disclosure is related to the field...
#
#                                               claims  \
# 0  What is claimed is: \n     \n       1. A dummy...
# 1  The invention claimed is: \n     \n       1. A...
# 2  What is claimed is: \n     \n       1. A metho...
# 3  What is claimed is: \n     \n       1. A metho...
# 4  What is claimed is: \n     \n         1 . A me...
#
#                                          description
# 0  CROSS-REFERENCE TO RELATED APPLICATION \n     ...
# 1  TECHNICAL FIELD \n     The present application...
# 2  BACKGROUND INFORMATION \n     Use of mobile na...
# 3  CROSS-REFERENCE TO RELATED APPLICATION—PROVISI...
# 4  CROSS-REFERENCE TO RELATED APPLICATION(S) \n  ...

# %%
df.shape
# Out:
# (1000, 5)
